# %%
import collections

class TrieNode:
    def __init__(self):
        self.isEnd = False
        self.visited = []
        self.pos = []
        self.children = collections.defaultdict(TrieNode)

class Trie:
    def __init__(self):
        self.root = TrieNode()
    
    def findStart(self, word):
        p = self.root
        for i,c in enumerate(word):
            if not p.children.get(c):
                break
            p = p.children.get(c)
        return p, i     
        
    def insert(self, word, bb):
        if word:
            p, i = self.findStart(word)
            # insert from root, p == root
            if i == 0:
                p = root.children[word[i]]
                for i in range(1,len(bb)-1):
                    for j in range(1,len(bb[0])-1):
                        if bb[i][j] == word[i]:
                            p.pos.append((i,j))
                
        
        
        
        
#         p = self.root
#         p = root.children.get(word[0])
#         if p is None:
#             p = root.children[word[0]]
#             for i in range(1,len(bb)-1):
#                 for j in range(1,len(bb[0])-1):
#                     if bb[i][j] == word[0]:
#                         p.pos.append((i,j))
#         visited = 
#         for c in word[1:]:
#             p = p.children.get(c)
#             if p is None:
#                 p = p.children[c]
#                 p.visited = 
                        
        
    
    
class Solution:
    def findWords(self, board, words):
        """
        :type board: List[List[str]]
        :type word: str
        :rtype: bool
        """
        res = []
        bb = [[0 for i in range(len(board[0])+2)] for j in range(len(board)+2)]
        for i in range(len(board)):
            for j in range(len(board[0])):
                bb[i+1][j+1] = board[i][j]
        tr = Trie()
        for word in words:
            tr.insert(word)
        
        
        
#         def solve(bb, visited, word, pos):
# #             pdb.set_trace()
#             if not word:
#                 return True
#             else:
#                 for (i,j) in pos:
#                     if (i,j) not in visited and bb[i][j] == word[0]:
#                         visited.append((i,j))
#                         if solve(bb, visited, word[1:], [(i-1,j),(i+1,j),(i,j-1),(i,j+1)]):
#                             return True
#                         visited.pop()
#                 return False
            
#         bb = [[0 for i in range(len(board[0])+2)] for j in range(len(board)+2)]
#         res = []
#         for word in set(words):
#             visited = []
#             pos = []
#             for i in range(len(board)):
#                 for j in range(len(board[0])):
#                     bb[i+1][j+1] = board[i][j]
#                     if board[i][j] == word[0]:
#                         pos.append((i+1,j+1))
#             if solve(bb, visited, word, pos):
#                 res.append(word)
#         return res

# %%
board = [
  ['o','a','a','n'],
  ['e','t','a','e'],
  ['i','h','k','r'],
  ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]
